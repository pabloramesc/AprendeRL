# %% [markdown]
# # Train SARSA(lambda)
#
# SARSA(lambda) assigns each TD error backward through eligibility traces. The experiment uses deterministic `FrozenLake-v1` so the learned table can be inspected directly.

# %% [markdown]
# ## Defining update
#
# $$E_t(s,a)=\gamma\lambda E_{t-1}(s,a)+\mathbf 1\{s=S_t,a=A_t\},\qquad Q\leftarrow Q+\alpha\delta_tE_t.$$
#
# Here $E_t$ is the eligibility trace, $\delta_t$ the SARSA TD error, $\alpha$ the learning rate, $\gamma$ the discount factor, and $\lambda$ the trace-decay parameter.

# %%
import gymnasium as gym
import matplotlib.pyplot as plt
import numpy as np

from aprenderl import SARSALambda, SARSALambdaConfig
from aprenderl.utils import evaluate_policy

ENV_ID = "FrozenLake-v1"

# %%
env = gym.make(ENV_ID, is_slippery=False)
config = SARSALambdaConfig(
    trace_decay=0.9,
    exploration_steps=3_000,
    seed=7,
)

agent = SARSALambda(env, config=config)
agent.learn(total_timesteps=5_000, progress_bar=False)
env.close()

# %%
print("Q-table shape:", agent.q_table.shape)
print("Greedy policy:")
print(agent.q_table.argmax(axis=1).reshape(4, 4))
print("Updates:", agent.num_updates)

# %%
returns = np.asarray(agent.episode_returns)
window = min(20, len(returns))
moving_average = np.convolve(
    returns, np.ones(window) / window, mode="valid"
)

plt.figure(figsize=(8, 4))
plt.plot(returns, alpha=0.35, label="Episode return")
plt.plot(
    np.arange(window - 1, len(returns)),
    moving_average,
    label=f"{window}-episode average",
)
plt.xlabel("Episode")
plt.ylabel("Return")
plt.title(f"SARSA(lambda) training on {ENV_ID}")
plt.legend()
plt.grid(alpha=0.2)
plt.show()

# %% [markdown]
# ## Watch the trained policy
#
# This opens a window and runs 5 episodes using deterministic actions.

# %%
evaluation_env = gym.make(
    ENV_ID, render_mode="human", is_slippery=False
)
try:
    result = evaluate_policy(
        agent, evaluation_env, episodes=5, deterministic=True
    )
finally:
    evaluation_env.close()

print("Episode returns:", result.returns)
print(f"Mean return: {result.mean_return:.1f} +/- {result.return_std:.1f}")
